# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'deepfake-detection-challenge:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-competitions-data%2Fkaggle-v2%2F16880%2F858837%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240927%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240927T165301Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,deepfake-detection-challenge-dataset-face-images:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F5682694%2F9370003%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240927%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240927T165301Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading deepfake-detection-challenge, 4439352219 bytes compressed
# [==================================================] 4439352219 bytes downloaded
# Downloaded and uncompressed: deepfake-detection-challenge
# Downloading deepfake-detection-challenge-dataset-face-images, 126132864 bytes compressed
# [==================================================] 126132864 bytes downloaded
# Downloaded and uncompressed: deepfake-detection-challenge-dataset-face-images
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eqnoqyfquo_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbnygxtwek_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dzyuwjkjui_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/anpuvshzoo_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/caifxvsozs_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybgughjxh_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chtapglbcj_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cobjrlugvp_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cprhtltsjp_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/caifxvsozs_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkzvdrzcnr_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cprhtltsjp_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cobjrlugvp_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bilnggbxgu_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bxzakyopjf_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehccixxzoe_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/caifxvsozs_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehccixxzoe_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/edyncaijwx_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/drcyabprvt_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/anpuvshzoo_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/duycddgtrl_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/drcyabprvt_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybgughjxh_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bxzakyopjf_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwipwzzxxu_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cobjrlugvp_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybumesmpk_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bxzakyopjf_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybumesmpk_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/duycddgtrl_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/drcyabprvt_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eqnoqyfquo_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwipwzzxxu_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/edyncaijwx_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bxzakyopjf_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cprhtltsjp_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybgughjxh_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cizlkenljw_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybumesmpk_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ddepeddixj_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwipwzzxxu_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/duycddgtrl_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ddepeddixj_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cobjrlugvp_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkzvdrzcnr_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chtapglbcj_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/duycddgtrl_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/anpuvshzoo_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/anpuvshzoo_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybgughjxh_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cizlkenljw_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bilnggbxgu_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eqnoqyfquo_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chviwxsfhg_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbnygxtwek_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/drcyabprvt_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cobjrlugvp_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/anpuvshzoo_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ddepeddixj_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybumesmpk_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bzythlfnhq_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwipwzzxxu_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbnygxtwek_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eqnoqyfquo_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bxzakyopjf_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehccixxzoe_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dlpoieqvfb_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkzvdrzcnr_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cizlkenljw_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cizlkenljw_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ddepeddixj_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dzyuwjkjui_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bilnggbxgu_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/duycddgtrl_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cfxkpiweqt_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eqnoqyfquo_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehccixxzoe_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cprhtltsjp_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eggbjzxnmg_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cobjrlugvp_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chtapglbcj_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chtapglbcj_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beboztfcme_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehccixxzoe_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dzyuwjkjui_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/edyncaijwx_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chviwxsfhg_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chviwxsfhg_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bilnggbxgu_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dzyuwjkjui_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cppdvdejkc_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cprhtltsjp_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chtapglbcj_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bpapbctoao_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbnygxtwek_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/edyncaijwx_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ddepeddixj_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/caifxvsozs_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/djxdyjopjd_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ddepeddixj_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehtdtkmmli_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbnygxtwek_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/efwfxwwlbw_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/edyncaijwx_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/afoovlsmtx_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkzvdrzcnr_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/asaxgevnnp_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkzvdrzcnr_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybgughjxh_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bdnaqemxmr_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/axntxmycwd_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/duycddgtrl_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/drcyabprvt_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bddjdhzfze_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dzyuwjkjui_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dzyuwjkjui_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aytzyidmgs_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eqnoqyfquo_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ccfoszqabv_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/erlvuvjsjf_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ahqqqilsxt_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/beyebyhrph_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/drcyabprvt_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/caifxvsozs_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bulkxhhknf_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhcndnuwta_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwhlgysghg_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aelfnikyqj_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/crezycjqyk_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dhxctgyoqj_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckkuyewywx_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgvhtpzknn_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/agrmhtjdlk_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybumesmpk_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ekcrtigpab_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chviwxsfhg_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ajqslcypsw_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bilnggbxgu_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dakiztgtnw_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/avmjormvsx_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eudeqjhdfd_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwipwzzxxu_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cmbzllswnl_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/brwrlczjvi_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/egghxjjmfg_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/caifxvsozs_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/abarnvbtwb_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bwipwzzxxu_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkzvdrzcnr_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/eckvhdusax_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ecujsjhscd_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dsjbknkujw_5.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cyxlcuyznd_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/atkdltyyen_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bffwsjxghk_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/cpjxareypw_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bgwmmujlmc_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bmjzrlszhi_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_8.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ehccixxzoe_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dkuayagnmc_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dxbqjxrhin_7.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/clrycekyst_2.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/chviwxsfhg_4.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/bejhvclboh_0.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ellavthztb_3.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ckjaibzfxa_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/edyncaijwx_1.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/aybumesmpk_9.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/ciyoudyhly_6.png
# /kaggle/input/deepfake-detection-challenge-dataset-face-images/real/dbtbbhakdv_2.png
# ...
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bzmdrafeex.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eudeqjhdfd.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aybumesmpk.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ciyoudyhly.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eiwopxzjfn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ahbweevwpv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bvgwelbeof.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bffwsjxghk.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dsjbknkujw.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/benmsfzfaz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bhbdugnurr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bbvgxeczei.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dbtbbhakdv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/beyebyhrph.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cettndmvzl.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bdgipnyobr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ecnihjlfyt.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/avibnnhwhp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/clihsshdkq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ebeknhudxq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bkwxhglwct.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/egbbcxcuqy.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/apogckdfrz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bjsmaqefoi.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aapnvogymq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cdphtzqrvp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/avgiuextiz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aqpnvjhuzw.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/etdcqxabww.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dbzcqmxzaj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/crktehraph.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/asaxgevnnp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ecuvtoltue.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bmjzrlszhi.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ddqccgmtka.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bkmdzhfzfh.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bdnaqemxmr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aelfnikyqj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aczrgyricp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/btmsngnqhv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/axntxmycwd.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eqvuznuwsa.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dptbnjnkdg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bmehkyanbj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cxttmymlbn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/avtycwsgyb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/agdkmztvby.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bqdjzqhcft.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/agrmhtjdlk.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ecwaxgutkc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bxzakyopjf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cyclgfjdrv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ajwpjhrbcv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/czkdanyadc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cwbacdwrzo.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/azsmewqghg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ebebgmtlcu.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/awukslzjra.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cksanfsjhc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/curpwogllm.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bulkxhhknf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dntkzzzcdh.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/erqgqacbqe.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/axczxisdtb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bndybcqhfr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/afoovlsmtx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/esyhwdfnxs.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dsdoseflas.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cppdvdejkc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cdbsbdymzd.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eixwxvxbbn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ayqvfdhslr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cknyxaqouy.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ddpvuimigj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bqeiblbxtl.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/asdpeebotb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/akxoopqjqz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cobjrlugvp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/awnwkrqibf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eqjscdagiv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/chviwxsfhg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cbltdtxglo.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cxrfacemmq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cfxkpiweqt.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bweezhfpzp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eivxffliio.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dbhrpizyeq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/adylbeequz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aevrfsexku.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bbhpvrmbse.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bilnggbxgu.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dhxctgyoqj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/avssvvsdhz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bmbbkwmxqj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/apgjqzkoma.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cuzrgrbvil.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/emgjphonqb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/chtapglbcj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/alninxcyhg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dtbpmdqvao.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ceymbecxnj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dlpoieqvfb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dbhoxkblzx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/arkroixhey.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ehevsxtecd.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/beboztfcme.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cwsbspfzck.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ahfazfbntc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cgvrgibpfo.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bqkdbcqjvb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dptrzdvwpg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dzyuwjkjui.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aybgughjxh.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aknmpoonls.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dofusvhnib.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bggsurpgpr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/diomeixhrg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/blzydqdfem.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eahlqmfvtj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eggbjzxnmg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ebchwmwayp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eebrkicpry.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bhaaboftbc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/caifxvsozs.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/amowujxmzc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/atkdltyyen.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/alaijyygdv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bmioepcpsx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eqnoqyfquo.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/errocgcham.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bejhvclboh.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bguwlyazau.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dbnygxtwek.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bydaidkpdp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ensyyivobf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/avfitoutyn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/drtbksnpol.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bnbuonyoje.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aettqgevhz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dxuliowugt.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/asvcrfdpnq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bpapbctoao.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bgwmmujlmc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dhevettufk.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eepezmygaq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/duvyaxbzvp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dqzreruvje.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/byyqectxqa.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cthdnahrkh.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dxuplhwvig.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cmbzllswnl.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dtocdfbwca.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/blpchvmhxx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/epymyyiblu.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bjkmjilrxp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bwhlgysghg.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/btjwbtsgln.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bopqhhalml.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bwuwstvsbw.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bghphrsfxf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/caqbrkogkb.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bmjmjmbglm.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ctpqeykqdp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/covdcysmbi.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/abofeumbvv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cglxirfaey.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/erlvuvjsjf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dafhtipaml.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bgvhtpzknn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ckbdwedgmc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/eukvucdetx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dkdwxmtpuo.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aipfdnwpoo.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/djvtbgwdcc.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cyxlcuyznd.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cycacemkmt.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bctvsmddgq.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cwrtyzndpx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aytzyidmgs.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ddjggcasdw.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/edyncaijwx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bdxuhamuqx.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ehfiekigla.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dnyvfblxpm.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/byunigvnay.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cvaksbpssm.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/aladcziidp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/bsfmwclnqy.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ddhfabwpuz.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/avnqydkqjj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dhkwmjxwrn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dgxrqjdomn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dzwkmcwkwl.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/czfunozvwp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dkzvdrzcnr.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dcamvmuors.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/btiysiskpf.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/metadata.json
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/esyrimvzsa.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/ddepeddixj.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/atvmxvwyns.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/cdaxixbosp.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dqqtjcryjv.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/dubiroskqn.mp4
# /kaggle/input/deepfake-detection-challenge/train_sample_videos/akzbnazxtz.mp4

# %% [markdown]
# # Training Data Preparation

# %%
# !pip install keras-nightly
# !pip install tensorflow
# !pip install keras
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: keras-nightly in /usr/local/lib/python3.10/dist-packages (3.6.0.dev2024092903)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras-nightly) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import os
import cv2
import numpy as np
import pickle
import tensorflow
from collections import defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.inception_v3 import preprocess_input


# Constants
IMG_SIZE = (299, 299)  # Target image size for InceptionV3
MAX_FRAMES = 10        # Maximum number of frames per sequence
REAL_DIR = 'real'      # Directory containing images of real samples
FAKE_DIR = 'fake'      # Directory containing images of fake samples

def load_images_from_directory(directory, label):
    """
    Load images from the specified directory, group them by videoname, preprocess, and pad sequences.

    Parameters:
    - directory (str): Path to the directory containing images.
    - label (int): Label for the samples (0 for real, 1 for fake).

    Returns:
    - data (np.array): Array of processed sequences of images.
    - labels (np.array): Array of corresponding labels.
    """
    data = []
    labels = []
    video_frames = defaultdict(list)  # Dictionary to hold frames grouped by videoname

    # Iterate over all images in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.png'):
            # Extract the videoname (before the first underscore)
            video_name = filename.split('_')[0]
            filepath = os.path.join(directory, filename)
            img = cv2.imread(filepath)

            if img is not None:
                # Resize and preprocess the image
                img = cv2.resize(img, IMG_SIZE)
                img = img_to_array(img)
                img = preprocess_input(img)  # Preprocess using InceptionV3 preprocessing
                video_frames[video_name].append(img)

    # Process each set of images grouped by videoname
    for frames in video_frames.values():
        # Pad with zeros if frames are less than MAX_FRAMES
        while len(frames) < MAX_FRAMES:
            frames.append(np.zeros((299, 299, 3)))  # Zero-padding for missing frames

        # Limit to MAX_FRAMES if more frames are present
        frames = frames[:MAX_FRAMES]

        data.append(frames)
        labels.append(label)

    return np.array(data), np.array(labels)

# %%
# Load real and fake images
REAL_DIR = "/kaggle/input/deepfake-detection-challenge-dataset-face-images/real"
FAKE_DIR = "/kaggle/input/deepfake-detection-challenge-dataset-face-images/fake"
# Load real and fake images
x_real, y_real = load_images_from_directory(REAL_DIR, label=0)  # Label 0 for real
x_fake, y_fake = load_images_from_directory(FAKE_DIR, label=1)  # Label 1 for fake

# %%
# Combine real and fake data
x_data = np.concatenate([x_real, x_fake], axis=0)
y_data = np.concatenate([y_real, y_fake], axis=0)

# Split the data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.2, random_state=42, stratify=y_data)

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, TimeDistributed, Dropout, GlobalAveragePooling2D, Input

# Define the custom feature extractor as a Keras Model
def create_feature_extractor():
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    feature_extractor = tf.keras.Model(inputs=base_model.input, outputs=GlobalAveragePooling2D()(base_model.output))
    return feature_extractor

# Build the sequential model with TimeDistributed
def create_model():
    feature_extractor = create_feature_extractor()

    model = Sequential()
    model.add(Input(shape=(None, 299, 299, 3)))
    model.add(TimeDistributed(feature_extractor))
    model.add(LSTM(128, return_sequences=True)) # LSTM layer
    model.add(GRU(128)) # GRU layer
    model.add(Dropout(0.5)) # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer: binary classification

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Create and summarize the model
model = create_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed (TimeDistributed)   │ (None, None, 2048)          │      21,802,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, None, 128)           │       1,114,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 128)                 │          99,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,024,801 (87.83 MB)
#  Trainable params: 22,990,369 (87.70 MB)
#  Non-trainable params: 34,432 (134.50 KB)

# %%
model.fit(x_train, y_train, epochs=20, batch_size=10, validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 307s 7s/step - accuracy: 0.5548 - loss: 0.7098 - val_accuracy: 0.4839 - val_loss: 0.8270
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 65s 5s/step - accuracy: 0.5226 - loss: 0.7139 - val_accuracy: 0.4839 - val_loss: 0.7658
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 64s 5s/step - accuracy: 0.5901 - loss: 0.6616 - val_accuracy: 0.5806 - val_loss: 0.7366
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 64s 5s/step - accuracy: 0.6428 - loss: 0.6645 - val_accuracy: 0.5161 - val_loss: 0.7024
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step - accuracy: 0.5729 - loss: 0.6920 - val_accuracy: 0.4194 - val_loss: 0.8629
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.5851 - loss: 0.6578 - val_accuracy: 0.5161 - val_loss: 0.7316
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step - accuracy: 0.6869 - loss: 0.6491 - val_accuracy: 0.5806 - val_loss: 0.7526
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.4878 - loss: 0.7640 - val_accuracy: 0.4839 - val_loss: 0.7442
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.5612 - loss: 0.6697 - val_accuracy: 0.5161 - val_loss: 0.7049
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.6178 - loss: 0.6464 - val_accuracy: 0.5484 - val_loss: 0.7254
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.6523 - loss: 0.6218 - val_accuracy: 0.5161 - val_loss: 0.7583
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.6880 - loss: 0.6111 - val_accuracy: 0.5161 - val_loss: 0.8159
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.6231 - loss: 0.6695 - val_accuracy: 0.4516 - val_loss: 0.7925
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.5900 - loss: 0.6548 - val_accuracy: 0.4194 - val_loss: 0.8099
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.5924 - loss: 0.6772 - val_accuracy: 0.6129 - val_loss: 0.7113
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.6472 - loss: 0.6667 - val_accuracy: 0.5161 - val_loss: 0.7532
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.6323 - loss: 0.6212 - val_accuracy: 0.5484 - val_loss: 0.7381
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 62s 5s/step - accuracy: 0.7252 - loss: 0.5652 - val_accuracy: 0.4839 - val_loss: 0.8785
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.6623 - loss: 0.6185 - val_accuracy: 0.5806 - val_loss: 0.8210
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.6210 - loss: 0.6321 - val_accuracy: 0.4839 - val_loss: 0.7871

# %%
# Save the model in the .h5 format
model.save('/kaggle/working/deepfake_detection_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

# Load the model
model_path = '/kaggle/working/deepfake_detection_model.h5'
model = tf.keras.models.load_model(model_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Save model architecture
model_json = model.to_json()
with open('/kaggle/working/model_architecture.json', 'w') as json_file:
    json_file.write(model_json)

# Save model weights
model.save_weights('/kaggle/working/model.weights.h5')

# %%
import tensorflow as tf
from tensorflow.keras.models import model_from_json

# Load model architecture
with open('/kaggle/working/model_architecture.json', 'r') as json_file:
    model_json = json_file.read()

# Recreate the model from the architecture
model = model_from_json(model_json, custom_objects={'TimeDistributed': tf.keras.layers.TimeDistributed})

# Load model weights
model.load_weights('/kaggle/working/model.weights.h5')
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 398 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.inception_v3 import preprocess_input

# Load the trained model
#model = load_model('/kaggle/working/deepfake_detection_model_2.h5')

# Constants
IMG_SIZE = (299, 299)  # Image size expected by the model
MAX_FRAMES = 10        # Max frames to consider per video

def extract_frames_from_video(video_path, max_frames=MAX_FRAMES):
    """
    Extract and preprocess frames from a given video for prediction.

    Parameters:
    - video_path (str): Path to the input video file.
    - max_frames (int): Maximum number of frames to process from the video.

    Returns:
    - processed_frames (np.array): Array of processed frames ready for model prediction.
    """
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    processed_frames = []

    while cap.isOpened() and frame_count < max_frames:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize and preprocess the frame
        resized_frame = cv2.resize(frame, IMG_SIZE)
        frame_array = img_to_array(resized_frame)
        processed_frame = preprocess_input(frame_array)
        processed_frames.append(processed_frame)
        frame_count += 1

    cap.release()

    # Pad with zero frames if less than max_frames are present
    while len(processed_frames) < max_frames:
        processed_frames.append(np.zeros((299, 299, 3)))

    return np.array([processed_frames])

def predict_video(model, video_path):
    """
    Predict whether the video is REAL or FAKE based on extracted frames.

    Parameters:
    - model: The trained deepfake detection model.
    - video_path (str): Path to the input video file.

    Returns:
    - prediction (str): 'REAL' or 'FAKE' based on model prediction.
    """
    # Extract frames from the video
    frames = extract_frames_from_video(video_path)

    # Make predictions on frames
    predictions = model.predict(frames)
    print(predictions)
    # Aggregate predictions; if the average is above 0.5, classify as FAKE
    avg_prediction = np.mean(predictions)
    print(avg_prediction)
    if avg_prediction > 0.5:
        return 'FAKE'
    else:
        return 'REAL'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Example usage
# video_path = '/kaggle/input/deepfake-detection-challenge/test_videos/sqixhnilfm.mp4'  # Replace with your video file path
video_path = '/content/drive/MyDrive/Media.mp4'
result = predict_video(model, video_path)
print(f'The video is predicted to be: {result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# [[0.16868123]]
# 0.16868123
# The video is predicted to be: REAL
